# %% [markdown]
# **Why Data Reconciliation Matters?**
#
# In a production environment, internal records and third-party payment gateways (like Stripe or PayPal) rarely match perfectly. Network timeouts, partial refunds, and duplicate API calls create 'data drift.' As an engineer, the job isn't just to move data, but to ensure its integrity.

# %% [markdown]
# To build a robust auditor, I need messy data. I’m using the Faker library to synthesize 100 transactions, then intentionally injecting 3 types of common financial errors: missing records, amount discrepancies, and duplicates. This ensures the logic is battle-tested against edge cases.

# %%
import pandas as pd
from faker import Faker
import random

fake = Faker()
Faker.seed(42)

# %%
rows = 100
data = [{
    "TXN_ID": f"TXN-{1000 + i}",
    "Customer": fake.name(),
    "Amount": round(random.uniform(50.0, 500.0), 2),
    "Date": fake.date_between(start_date='-30d', end_date='today')
} for i in range(rows)]

df_internal = pd.DataFrame(data)

# 2. Create Gateway Statement (The Messy Version)
# Start with a copy, then inject errors
df_gateway = df_internal.copy()

# A. Simulate 5 Missing Transactions (Drop them)
df_gateway = df_gateway.drop(random.sample(range(rows), 5))

# B. Simulate 3 Amount Mismatches (Pricing/Fee errors)
mismatch_indices = df_gateway.index[:3]
df_gateway.loc[mismatch_indices, 'Amount'] = df_gateway.loc[mismatch_indices, 'Amount'] - 1.00

# C. Simulate 2 Duplicates (Bank double-processing)
duplicates = df_gateway.iloc[-2:]
df_gateway = pd.concat([df_gateway, duplicates], ignore_index=True)

print(f"Internal Count: {len(df_internal)} | Gateway Count: {len(df_gateway)}")
# Out:
# Internal Count: 100 | Gateway Count: 97

# %%
# Step 1: Flag duplicates in the gateway before merging
df_gateway['is_duplicate'] = df_gateway.duplicated(subset=['TXN_ID'], keep=False)

# Step 2: Merge the two datasets
# We join on TXN_ID to see what's missing or different
comparison = pd.merge(
    df_internal, 
    df_gateway[['TXN_ID', 'Amount', 'is_duplicate']], 
    on="TXN_ID", 
    how="left", 
    suffixes=('_Internal', '_Gateway')
)

# Step 3: Categorize the Discrepancies
def identify_issue(row):
    if pd.isna(row['Amount_Gateway']):
        return "MISSING_IN_GATEWAY"
    elif row['is_duplicate'] == True:
        return "DUPLICATE_IN_GATEWAY"
    elif row['Amount_Internal'] != row['Amount_Gateway']:
        return "AMOUNT_MISMATCH"
    else:
        return "MATCHED"

comparison['Audit_Status'] = comparison.apply(identify_issue, axis=1)

# Display a summary of findings
print(comparison['Audit_Status'].value_counts())
comparison.head(10)
# Out:
# Audit_Status
# MATCHED                 90
# MISSING_IN_GATEWAY       5
# DUPLICATE_IN_GATEWAY     4
# AMOUNT_MISMATCH          3
# Name: count, dtype: int64
#      TXN_ID           Customer  Amount_Internal        Date  Amount_Gateway  \
# 0  TXN-1000       Allison Hill           496.60  2026-02-01          495.60
# 1  TXN-1001         Brian Yang           219.97  2026-02-17          218.97
# 2  TXN-1002     Javier Johnson           436.39  2026-02-01          435.39
# 3  TXN-1003      Lance Hoffman            97.74  2026-02-17           97.74
# 4  TXN-1004      Jerry Ramirez           378.44  2026-01-22          378.44
# 5  TXN-1005  Caitlin Henderson           395.46  2026-02-04          395.46
# 6  TXN-1006       Tyler Rogers           266.91  2026-01-26          266.91
# 7  TXN-1007         Ian Cooper           497.72  2026-02-03          497.72
# 8  TXN-1008     Monica Herrera           105.45  2026-02-09          105.45
# 9  TXN-1009      Edward Fuller           125.87  2026-02-08          125.87
#
#   is_duplicate     Audit_Status
# 0        False  AMOUNT_MISMATCH
# 1        False  AMOUNT_MISMATCH
# 2        False  AMOUNT_MISMATCH
# 3        False          MATCHED
# 4        False          MATCHED
# 5        False          MATCHED
# 6        False          MATCHED
# 7        False          MATCHED
# 8        False          MATCHED
# 9        False          MATCHED

# %%
def style_audit(row):
    color = ''
    if row.Audit_Status == "AMOUNT_MISMATCH":
        color = 'background-color: #ffcccc' # Red
    elif row.Audit_Status == "MISSING_IN_GATEWAY":
        color = 'background-color: #ffffcc' # Yellow
    elif row.Audit_Status == "DUPLICATE_IN_GATEWAY":
        color = 'background-color: #cce5ff' # Blue
    return [color] * len(row)

# Show the first 20 rows with styling applied
comparison.head(20).style.apply(style_audit, axis=1)
# Out:
# <style type="text/css">
# #T_06dbf_row0_col0, #T_06dbf_row0_col1, #T_06dbf_row0_col2, #T_06dbf_row0_col3, #T_06dbf_row0_col4, #T_06dbf_row0_col5, #T_06dbf_row0_col6, #T_06dbf_row1_col0, #T_06dbf_row1_col1, #T_06dbf_row1_col2, #T_06dbf_row1_col3, #T_06dbf_row1_col4, #T_06dbf_row1_col5, #T_06dbf_row1_col6, #T_06dbf_row2_col0, #T_06dbf_row2_col1, #T_06dbf_row2_col2, #T_06dbf_row2_col3, #T_06dbf_row2_col4, #T_06dbf_row2_col5, #T_06dbf_row2_col6 {
#   background-color: #ffcccc;
# }
# </style>
# <table id="T_06dbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06dbf_level0_col0" class="col_heading level0 col0" >TXN_ID</th>
#       <th id="T_06dbf_level0_col1" class="col_heading level0 col1" >Customer</th>
#       <th id="T_06dbf_level0_col2" class="col_heading level0 col2" >Amount_Internal</th>
#       <th id="T_06dbf_level0_col3" class="col_heading level0 col3" >Date</th>
#       <th id="T_06dbf_level0_col4" class="col_heading level0 col4" >Amount_Gateway</th>
#       <th id="T_06dbf_level0_col5" class="col_heading level0 col5" >is_duplicate</th>
#       <th id="T_06dbf_level0_col6" class="col_heading level0 col6" >Audit_Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06dbf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06dbf_row0_col0" class="data row0 col0" >TXN-1000</td>
#       <td id="T_06dbf_row0_col1" class="data row0 col1" >Allison Hill</td>
#       <td id="T_06dbf_row0_col2" class="data row0 col2" >496.600000</td>
#       <td id="T_06dbf_row0_col3" class="data row0 col3" >2026-02-01</td>
#       <td id="T_06dbf_row0_col4" class="data row0 col4" >495.600000</td>
#       <td id="T_06dbf_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_06dbf_row0_col6" class="data row0 col6" >AMOUNT_MISMATCH</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06dbf_row1_col0" class="data row1 col0" >TXN-1001</td>
#       <td id="T_06dbf_row1_col1" class="data row1 col1" >Brian Yang</td>
#       <td id="T_06dbf_row1_col2" class="data row1 col2" >219.970000</td>
#       <td id="T_06dbf_row1_col3" class="data row1 col3" >2026-02-17</td>
#       <td id="T_06dbf_row1_col4" class="data row1 col4" >218.970000</td>
#       <td id="T_06dbf_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_06dbf_row1_col6" class="data row1 col6" >AMOUNT_MISMATCH</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_06dbf_row2_col0" class="data row2 col0" >TXN-1002</td>
#       <td id="T_06dbf_row2_col1" class="data row2 col1" >Javier Johnson</td>
#       <td id="T_06dbf_row2_col2" class="data row2 col2" >436.390000</td>
#       <td id="T_06dbf_row2_col3" class="data row2 col3" >2026-02-01</td>
#       <td id="T_06dbf_row2_col4" class="data row2 col4" >435.390000</td>
#       <td id="T_06dbf_row2_col5" class="data row2 col5" >False</td>
#       <td id="T_06dbf_row2_col6" class="data row2 col6" >AMOUNT_MISMATCH</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_06dbf_row3_col0" class="data row3 col0" >TXN-1003</td>
#       <td id="T_06dbf_row3_col1" class="data row3 col1" >Lance Hoffman</td>
#       <td id="T_06dbf_row3_col2" class="data row3 col2" >97.740000</td>
#       <td id="T_06dbf_row3_col3" class="data row3 col3" >2026-02-17</td>
#       <td id="T_06dbf_row3_col4" class="data row3 col4" >97.740000</td>
#       <td id="T_06dbf_row3_col5" class="data row3 col5" >False</td>
#       <td id="T_06dbf_row3_col6" class="data row3 col6" >MATCHED</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_06dbf_row4_col0" class="data row4 col0" >TXN-1004</td>
#       <td id="T_06dbf_row4_col1" class="data row4 col1" >Jerry Ramirez</td>
#       <td id="T_06dbf_row4_col2" class="data row4 col2" >378.440000</td>
#       <td id="T_06dbf_row4_col3" class="data row4 col3" >2026-01-22</td>
#       <td id="T_06dbf_row4_col4" class="data row4 col4" >378.440000</td>
#       <td id="T_06dbf_row4_col5" class="data row4 col5" >False</td>
#       <td id="T_06dbf_row4_col6" class="data row4 col6" >MATCHED</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_06dbf_row5_col0" class="data row5 col0" >TXN-1005</td>
#       <td id="T_06dbf_row5_col1" class="data row5 col1" >Caitlin Henderson</td>
#       <td id="T_06dbf_row5_col2" class="data row5 col2" >395.460000</td>
#       <td id="T_06dbf_row5_col3" class="data row5 col3" >2026-02-04</td>
#       <td id="T_06dbf_row5_col4" class="data row5 col4" >395.460000</td>
#       <td id="T_06dbf_row5_col5" class="data row5 col5" >False</td>
#       <td id="T_06dbf_row5_col6" class="data row5 col6" >MATCHED</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_06dbf_row6_col0" class="data row6 col0" >TXN-1006</td>
#       <td id="T_06dbf_row6_col1" class="data row6 col1" >Tyler Rogers</td>
#       <td id="T_06dbf_row6_col2" class="data row6 col2" >266.910000</td>
#       <td id="T_06dbf_row6_col3" class="data row6 col3" >2026-01-26</td>
#       <td id="T_06dbf_row6_col4" class="data row6 col4" >266.910000</td>
#       <td id="T_06dbf_row6_col5" class="data row6 col5" >False</td>
#       <td id="T_06dbf_row6_col6" class="data row6 col6" >MATCHED</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_06dbf_row7_col0" class="data row7 col0" >TXN-1007</td>
#       <td id="T_06dbf_row7_col1" class="data row7 col1" >Ian Cooper</td>
#       <td id="T_06dbf_row7_col2" class="data row7 col2" >497.720000</td>
#       <td id="T_06dbf_row7_col3" class="data row7 col3" >2026-02-03</td>
#       <td id="T_06dbf_row7_col4" class="data row7 col4" >497.720000</td>
#       <td id="T_06dbf_row7_col5" class="data row7 col5" >False</td>
#       <td id="T_06dbf_row7_col6" class="data row7 col6" >MATCHED</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_06dbf_row8_col0" class="data row8 col0" >TXN-1008</td>
#       <td id="T_06dbf_row8_col1" class="data row8 col1" >Monica Herrera</td>
#       <td id="T_06dbf_row8_col2" class="data row8 col2" >105.450000</td>
#       <td id="T_06dbf_row8_col3" class="data row8 col3" >2026-02-09</td>
#       <td id="T_06dbf_row8_col4" class="data row8 col4" >105.450000</td>
#       <td id="T_06dbf_row8_col5" class="data row8 col5" >False</td>
#       <td id="T_06dbf_row8_col6" class="data row8 col6" >MATCHED</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_06dbf_row9_col0" class="data row9 col0" >TXN-1009</td>
#       <td id="T_06dbf_row9_col1" class="data row9 col1" >Edward Fuller</td>
#       <td id="T_06dbf_row9_col2" class="data row9 col2" >125.870000</td>
#       <td id="T_06dbf_row9_col3" class="data row9 col3" >2026-02-08</td>
#       <td id="T_06dbf_row9_col4" class="data row9 col4" >125.870000</td>
#       <td id="T_06dbf_row9_col5" class="data row9 col5" >False</td>
#       <td id="T_06dbf_row9_col6" class="data row9 col6" >MATCHED</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_06dbf_row10_col0" class="data row10 col0" >TXN-1010</td>
#       <td id="T_06dbf_row10_col1" class="data row10 col1" >Michele Williams</td>
#       <td id="T_06dbf_row10_col2" class="data row10 col2" >378.470000</td>
#       <td id="T_06dbf_row10_col3" class="data row10 col3" >2026-02-02</td>
#       <td id="T_06dbf_row10_col4" class="data row10 col4" >378.470000</td>
#       <td id="T_06dbf_row10_col5" class="data row10 col5" >False</td>
#       <td id="T_06dbf_row10_col6" class="data row10 col6" >MATCHED</td>
#     </tr>
#     <tr>
#       <th id="T_06dbf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_06dbf_row11_col0" class="data row11 col0" >TXN-1011</td>
#       <td id="T_06dbf_row11_col1"

# %%
with pd.ExcelWriter("Reconciliation_Report.xlsx", engine='openpyxl') as writer:
    comparison.style.apply(style_audit, axis=1).to_excel(writer, index=False, sheet_name='Audit_Summary')

print("Report generated: Reconciliation_Report.xlsx")
# Out:
# Report generated: Reconciliation_Report.xlsx
